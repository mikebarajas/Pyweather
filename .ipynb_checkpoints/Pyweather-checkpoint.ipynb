# %%
# Dependencies
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import json
import random
from citipy import citipy
import openweathermapy.core as ow
#from config import api_key
from urllib.error import HTTPError

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}
weather_data = []

# %%
# Pull 500 Randomly Generated City Coordinates
lat = []
lon = []
cities = set([])

# While loop will populate cities set until it reaches 500 non repeating cities
while len(cities) < 1000: #Use this when you are finally ready to run program for 500 cities  
    lati = (random.randrange(-90,90,1))
    long = (random.randrange(-180,180,1))
    city = citipy.nearest_city(lati,long)
    city = city.city_name
    lat.append(lat)
    lon.append(long)
    cities.add(city)

cities = list(cities)

# %%
# Create a list to store JSONs of the weather data results and start a counter to run through randomly generated cities
weather_data = []
counter = []
count = 0

# Run a for loop that runs through the list of cities
for city in cities:
    if count < 500:
        try:
            data = ow.get_current(city, **settings)
            weather_data.append(data)
            count = count + 1
            counter.append(count)
        except Exception as e:
            print(city, ": not found  ", e)
            continue
            
            
# Generate a data frame from 500 callable cities    
summary = ["name", "dt","sys.country","coord.lat", "coord.lon", "main.temp_max", "main.humidity", "clouds.all", "wind.speed"]
data = [response(*summary) for response in weather_data]
column_names = ["City", "Time", "Country", "Latitude", "Longitude", "Temperature", "Humidity", "Cloud Coverage", "Wind Speed"]
weather_data = pd.DataFrame(data, index = counter, columns=column_names)
# Out:
# saleaula : not found   HTTP Error 404: Not Found
# formoso do araguaia : not found   HTTP Error 404: Not Found
# fulitun : not found   HTTP Error 404: Not Found
# angoche : not found   HTTP Error 404: Not Found
# yuzhno-yeniseyskiy : not found   HTTP Error 404: Not Found
# babanusah : not found   HTTP Error 404: Not Found
# lolua : not found   HTTP Error 404: Not Found
# halalo : not found   HTTP Error 404: Not Found
# erenhot : not found   HTTP Error 404: Not Found
# jinchengjiang : not found   HTTP Error 404: Not Found
# karamea : not found   HTTP Error 404: Not Found
# novolvovsk : not found   HTTP Error 404: Not Found
# grand centre : not found   HTTP Error 404: Not Found
# umm ruwabah : not found   HTTP Error 404: Not Found
# samalaeulu : not found   HTTP Error 404: Not Found
# jhikargachha : not found   HTTP Error 404: Not Found
# toliary : not found   HTTP Error 404: Not Found
# makat : not found   HTTP Error 404: Not Found
# tidore : not found   HTTP Error 404: Not Found
# tongzi : not found   HTTP Error 404: Not Found
# olafsvik : not found   HTTP Error 404: Not Found
# garowe : not found   HTTP Error 404: Not Found
# bajo baudo : not found   HTTP Error 404: Not Found
# orgun : not found   HTTP Error 404: Not Found
# hendijan : not found   HTTP Error 404: Not Found
# sarh : not found   HTTP Error 404: Not Found
# guajara-mirim : not found   HTTP Error 404: Not Found
# mananara : not found   HTTP Error 404: Not Found
# mudyuga : not found   HTTP Error 404: Not Found
# nauta : not found   HTTP Error 404: Not Found
# qibili : not found   HTTP Error 404: Not Found
# itarema : not found   HTTP Error 404: Not Found
# tuggurt : not found   HTTP Error 404: Not Found
# fenoarivo : not found   HTTP Error 404: Not Found
# aflu : not found   HTTP Error 404: Not Found
# abu samrah : not found   HTTP Error 404: Not Found
# manica : not found   HTTP Error 404: Not Found
# bolungarvik : not found   HTTP Error 404: Not Found
# loutrakion : not found   HTTP Error 404: Not Found
# tunxi : not found   HTTP Error 404: Not Found
# temaraia : not found   HTTP Error 404: Not Found
# bone : not found   HTTP Error 404: Not Found
# nara : not found   HTTP Error 404: Not Found
# achisay : not found   HTTP Error 404: Not Found
# tabiauea : not found   HTTP Error 404: Not Found
# bereda : not found   HTTP Error 404: Not Found
# tarudant : not found   HTTP Error 404: Not Found
# gat : not found   HTTP Error 404: Not Found
# ahumada : not found   HTTP Error 404: Not Found
# rungata : not found   HTTP Error 404: Not Found
# raudeberg : not found   HTTP Error 404: Not Found
# shintomi : not found   HTTP Error 404: Not Found
# marcona : not found   HTTP Error 404: Not Found
# sayanskiy : not found   HTTP Error 404: Not Found
# storforshei : not found   HTTP Error 404: Not Found
# miandoab : not found   HTTP Error 404: Not Found
# warqla : not found   HTTP Error 404: Not Found
# umzimvubu : not found   HTTP Error 404: Not Found
# pochutla : not found   HTTP Error 404: Not Found
# baghmara : not found   HTTP Error 404: Not Found
# kaili : not found   HTTP Error 404: Not Found
# soyo : not found   HTTP Error 404: Not Found
# odweyne : not found   HTTP Error 404: Not Found
# satitoa : not found   HTTP Error 404: Not Found
# sakakah : not found   HTTP Error 404: Not Found
# bababe : not found   HTTP Error 404: Not Found
# phan rang : not found   HTTP Error 404: Not Found
# akyab : not found   HTTP Error 404: Not Found
# sri aman : not found   HTTP Error 404: Not Found
# ipixuna : not found   HTTP Error 404: Not Found

# %%
# Generate a print out list of cities
cities_list = weather_data
cities_list.to_csv("Cities_Output.csv")
# Out:
#                     City        Time Country  Latitude  Longitude  \
# 1  San Miguel de Tucuman  1510970400      AR    -26.82     -65.22
# 2                  Kolda  1510974742      SN     12.88     -14.95
# 3         Ribeira Grande  1510974742      PT     38.52     -28.70
# 4                Diofior  1510974742      SN     14.18     -16.67
# 5            Bandarbeyla  1510974668      SO      9.49      50.81
#
#    Temperature  Humidity  Cloud Coverage  Wind Speed
# 1        77.00        50               0        4.70
# 2        69.46        71              48        2.77
# 3        67.84        98             100       28.99
# 4        73.28        70              56        7.07
# 5        80.48       100               0       20.83

# %%
# Build a scatter plot for lat v. temp
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Temperature(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatvMaxTemp.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for lat v. humidity
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude v. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatvHum.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for temp v. cloudiness
plt.scatter(weather_data["Latitude"], weather_data["Cloud Coverage"], marker="o")

# Incorporate the other graph properties
plt.title("City Laitude v. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatvCloudiness.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for temp v. wind speed
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude v. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LatvWind.png")

# Show plot
plt.show()
